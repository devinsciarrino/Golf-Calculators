# %%
! pip install -e
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
from hardy_golf import hardy_distribution_markov

scores, pmf = hardy_distribution_markov(4, 0.07, 0.07, 10)

print("Scores:", scores)
print("PMF:", pmf)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from hardy_golf import hardy_distribution_markov
#       3 scores, pmf = hardy_distribution_markov(4, 0.07, 0.07, 10)
#       5 print("Scores:", scores)
#
# ImportError: cannot import name 'hardy_distribution_markov' from 'hardy_golf' (unknown location)
